# %%
import pandas as pd
import numpy as np

# %%
# In this lab, you will use learningSet.csv file which you already have cloned in today's activities.
data = pd.read_csv('learningSet_clean.csv')
data.head()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_17700\2434814684.py:2: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('learningSet_clean.csv')
#    ODATEDW OSOURCE  TCODE STATE    ZIP MAILCODE   DOB NOEXCH MDMAUD DOMAIN  \
# 0     8901     GRI      0    IL  61081        A  3712      0   XXXX     T2
# 1     9401     BOA      1    CA  91326        A  5202      0   XXXX     S1
# 2     9001     AMH      1    NC  27017        A     0      0   XXXX     R2
# 3     8701     BRY      0    CA  95953        A  2801      0   XXXX     R2
# 4     8601     NaN      0    FL  33176        A  2001      0   XXXX     S2
#
#    ...  TARGET_D  HPHONE_D RFA_2R  RFA_2F RFA_2A  MDMAUD_R  MDMAUD_F  \
# 0  ...       0.0         0      L       4      E         X         X
# 1  ...       0.0         0      L       2      G         X         X
# 2  ...       0.0         1      L       4      E         X         X
# ...

# %%
categorical = data.select_dtypes(np.object)
categorical.head()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_17700\3545681673.py:1: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   categorical = data.select_dtypes(np.object)
#   OSOURCE STATE    ZIP MAILCODE NOEXCH MDMAUD DOMAIN HOMEOWNR GENDER VETERANS  \
# 0     GRI    IL  61081        A      0   XXXX     T2      NaN      F      NaN
# 1     BOA    CA  91326        A      0   XXXX     S1        H      M      NaN
# 2     AMH    NC  27017        A      0   XXXX     R2        U      M      NaN
# 3     BRY    CA  95953        A      0   XXXX     R2        U      F      NaN
# 4     NaN    FL  33176        A      0   XXXX     S2        H      F      NaN
#
#    ... RFA_12 RFA_14 RFA_16 RFA_18 RFA_2R RFA_2A MDMAUD_R MDMAUD_F MDMAUD_A  \
# ...

# %%
# 1. Check for null values in all the columns
nulls_df = pd.DataFrame(categorical.isna().sum()/len(categorical))
nulls_df.columns = ['nulls_percentage']
nulls_df_filtered = nulls_df[nulls_df['nulls_percentage']>0].sort_values(by=['nulls_percentage'],ascending=False)
print('There are' , len(nulls_df_filtered), 'columns with null values.')
nulls_df_filtered
# Out:
# There are 18 columns with null values.
#           nulls_percentage
# VETERANS          0.890727
# HOMEOWNR          0.232969
# RFA_18            0.222855
# RFA_16            0.213988
# RFA_14            0.197742
# RFA_9             0.117857
# RFA_11            0.109232
# RFA_12            0.093521
# RFA_7             0.093007
# RFA_6             0.037280
# RFA_8             0.036798
# GENDER            0.030992
# DOMAIN            0.024274
# RFA_4             0.024232
# RFA_3             0.020438
# OSOURCE           0.009726
# GEOCODE2          0.003343
# NOEXCH            0.000073

# %%
# 2. Exclude the following variables by looking at the definitions. Create a new empty list called drop_list. 
# We will append this list and then drop all the columns in this list later:

# OSOURCE - symbol definitions not provided, too many categories
# ZIP CODE - we are including state already

# %%
drop_list = []
drop_list.append('OSOURCE')
drop_list.append('ZIP')

# %%
drop_list
# Out:
# ['OSOURCE', 'ZIP']

# %%
# 3. Identify columns that over 85% missing values
nulls_df_filtered2 = nulls_df[nulls_df['nulls_percentage']>0.85].sort_values(by=['nulls_percentage'],ascending=False)
print('There are' , len(nulls_df_filtered2), 'columns with 85% null values.')
nulls_df_filtered2
# Out:
# There are 1 columns with 85% null values.
#           nulls_percentage
# VETERANS          0.890727

# %%
cols_85 = list(nulls_df[nulls_df['nulls_percentage']>0.85].T.columns)
for col in cols_85:
    drop_list.append(col)

# %%
# 4. Remove those columns from the dataframe
categorical = categorical.drop(columns=drop_list)
categorical
# Out:
#       STATE MAILCODE NOEXCH MDMAUD DOMAIN HOMEOWNR GENDER RFA_2 RFA_3 RFA_4  \
# 0        IL        A      0   XXXX     T2      NaN      F   L4E   S4E   S4E
# 1        CA        A      0   XXXX     S1        H      M   L2G   A2G   A2G
# 2        NC        A      0   XXXX     R2        U      M   L4E   S4E   S4E
# 3        CA        A      0   XXXX     R2        U      F   L4E   S4E   S4E
# 4        FL        A      0   XXXX     S2        H      F   L2F   A2F   A2F
# ...     ...      ...    ...    ...    ...      ...    ...   ...   ...   ...
# 95407    AK        A      0   XXXX     C2      NaN      M   L1G   F1G   F1G
# 95408    TX        A      0   XXXX     C1        H      M   L1F   NaN   NaN
# 95409    MI        A      0   XXXX     C3      NaN      M   L3E   S4E   S4E
# 95410    CA        A      0   XXXX     C1        H      F   L4F   S4F   A3F
# 95411    NC        A      0   C1CM     C1        U      F   L1G   A1G   A1G
#
# ...

# %%
# 5. Reduce the number of categories in the column GENDER. The column should only have either "M" for males, "F" for females,
# and "other" for all the rest

# Note that there are a few null values in the column. We will first replace those null values using the code below:

# %% [markdown]
# print(categorical['GENDER'].value_counts())
#
# categorical['GENDER'] = categorical['GENDER'].fillna('F')

# %%
categorical['GENDER'].value_counts()
# Out:
# F    51277
# M    39094
# U     1715
# J      365
# C        2
# A        2
# Name: GENDER, dtype: int64

# %%
def clean_gender(x):
    g = ['F','M']
    if x in g:
        return x
    else:
        return 'OTHER'

categorical['GENDER'] = list(map(clean_gender,categorical['GENDER']))
categorical['GENDER'].value_counts()
# Out:
# F        51277
# M        39094
# OTHER     5041
# Name: GENDER, dtype: int64
